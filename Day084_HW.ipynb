# %% [markdown]
# ## Work
# ### 請結合前面的知識與程式碼，比較不同的 regularization 的組合對訓練的結果與影響：如 dropout, regularizers, batch-normalization 等

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import Dropout


def build_mlp(input_shape, rgl , output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2, lrr=1e-4):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),
                                   kernel_regularizer=rgl(lrr)
                                  )(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1),kernel_regularizer=rgl(lrr))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
from keras.regularizers import l1, l2, l1_l2
Dropout_EXP = [0.1, 0.2, 0.4]
rgls = [l1,l2,l1_l2]
LEARNING_RATE = 1e-4
EPOCHS=50 
BATCH_SIZE = 256
Dropout_EXP = [0.1, 0.2, 0.4]

# %%
## 超參數設定
LEARNING_RATE = 1e-4
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95

"""
建立實驗組合
"""
Dropout_EXP = [0.1, 0.2, 0.4]
LAYER_NEURONS = [[128, 128, 128], [128, 256, 256], [128, 256, 512]]

from keras.layers import Dropout
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

results = {}
"""
以迴圈方式遍歷組合來訓練模型
"""
for i, (layer_neurons, drp_rate) in enumerate(itertools.product(LAYER_NEURONS, Dropout_EXP)):
    print("Numbers of exp: %i, layer: %s, dropout_rate: %.2f" % (i, layer_neurons, drp_rate))
    model = build_mlp(input_shape=x_train.shape[1:], num_neurons=layer_neurons, drp_ratio=drp_rate)
    model.summary()
    optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              verbose=0,
              shuffle=True)

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["acc"],
                             'valid-acc': model.history.history["val_acc"]}
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0812 23:57:37.718856 139620787222336 deprecation_wrapper.py:119] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0812 23:57:37.727536 139620787222336 deprecation_wrapper.py:119] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0812 23:57:37.728957 139620787222336 deprecation_wrapper.py:119] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0812 23:57:37.736391 139620787222336 deprecation_wrapper.py:119] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0812 23:57:37.739815 139620787222336 deprecation.py:506] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0812 23:57:37.789833 139620787222336 deprecation_wrapper.py:119] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0812 23:57:37.793553 139620787222336 deprecation_wrapper.py:119] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0812 23:57:37.841457 139620787222336 deprecation.py:323] From /home/jianhao/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Numbers of exp: 0, layer: [128, 128, 128], dropout_rate: 0.10
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 128)               393344
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 427,658
# Trainable params: 427,658
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

for i, (rgl, drp_rate) in enumerate(itertools.product(rgls, Dropout_EXP)):
    print("Numbers of exp: %i, reg: %s, dropout_rate: %.2f" % (i,strrgl, drp_rate))
    model = build_mlp(input_shape=x_train.shape[1:], rgl =rgl, drp_ratio=drp_rate)
    model.summary()
    optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              verbose=0,
              shuffle=True)

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["acc"],
                             'valid-acc': model.history.history["val_acc"]}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-15a6158a7221> in <module>
#       5
#       6 for i, (rgl, drp_rate) in enumerate(itertools.product(rgls, Dropout_EXP)):
# ----> 7     print("Numbers of exp: %i, reg: %s, dropout_rate: %.2f" % (i,strrgl, drp_rate))
#       8     model = build_mlp(input_shape=x_train.shape[1:], rgl =rgl, drp_ratio=drp_rate)
#       9     model.summary()
#
# NameError: name 'strrgl' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""

In [23]:
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()

# %%
#############resetart here 
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
train, test = keras.datasets.cifar10.load_data()
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y    

x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)
# Out:
# Using TensorFlow backend.

# %%
'''
def build_mlp():
    """Code Here
    建立你的神經網路
    """
    return model

'''
from keras.regularizers import l1, l2, l1_l2
from keras.layers import Dropout

"""
建立神經網路，並加入 dropout layer
"""
def build_mlp(input_shape, regulars = l1,output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   kernel_regularizer=regulars(),
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   kernel_regularizer=regulars(),
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""

LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
Dropout_EXP = [0.1, 0.2, 0.4]
regs = [l1,l2,l1_l2]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""

import keras.backend as K
K.clear_session()
model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=Dropout_EXP[0],regulars=l1)
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["acc"]
valid_acc = model.history.history["val_acc"]

# %%
import keras.backend as K
results = {}
for i, (reg, drp_ratio) in enumerate(itertools.product(regs, Dropout_EXP)):
    K.clear_session()
    #model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=Dropout_EXP[0],regulars=l1)
    model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=drp_ratio,regulars=reg)
    model.summary()
    #optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              #verbose=0,
              shuffle=True)
    exp_name_tag = ("reg %s exp-%s" % (reg.__name__,i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["acc"],
                             'valid-acc': model.history.history["val_acc"]}
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 198.6069 - acc: 0.2050 - val_loss: 41.0482 - val_acc: 0.2716
# Epoch 2/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 19.0649 - acc: 0.1124 - val_loss: 7.2305 - val_acc: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.0853 - acc: 0.0988 - val_loss: 2.6432 - val_acc: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4851 - acc: 0.0997 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0992 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0982 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0986 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0972 - val_loss: 2.4624 - val_acc: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0980 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0996 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0974 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0968 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0993 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0977 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1003 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0977 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0986 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0978 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0984 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0997 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0983 - val_loss: 2.4624 - val_acc: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0979 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0969 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0977 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0993 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0974 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0985 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0990 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0986 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0996 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0984 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0959 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1003 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1002 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0980 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0981 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0963 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0985 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0988 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0965 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0995 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0961 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0988 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0978 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0991 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0982 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0971 - val_loss: 2.4625 - val_acc: 0.1000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 198.6016 - acc: 0.1723 - val_loss: 40.9339 - val_acc: 0.2355
# Epoch 2/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 19.0301 - acc: 0.1109 - val_loss: 7.2580 - val_acc: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.0980 - acc: 0.0990 - val_loss: 2.6426 - val_acc: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4842 - acc: 0.1012 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0986 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1000 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0991 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0975 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0994 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0990 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0982 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0997 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0979 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0978 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0994 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0963 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0965 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1012 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0992 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0998 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0975 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0995 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0985 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0969 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0987 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0979 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0979 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1000 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0975 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0994 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0960 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0976 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0992 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0981 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0982 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4626 - acc: 0.0984 - val_loss: 2.4624 - val_acc: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0978 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0999 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0994 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0976 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0955 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0992 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0993 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0980 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0970 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1006 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0962 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 198.7188 - acc: 0.1496 - val_loss: 41.0127 - val_acc: 0.2114
# Epoch 2/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 19.0734 - acc: 0.1064 - val_loss: 7.2515 - val_acc: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.0969 - acc: 0.0975 - val_loss: 2.6411 - val_acc: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4838 - acc: 0.0984 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4627 - acc: 0.0976 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4627 - acc: 0.0979 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4627 - acc: 0.0990 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0976 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4627 - acc: 0.0967 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0952 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0987 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4627 - acc: 0.0975 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0994 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.1023 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0983 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4627 - acc: 0.0993 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0988 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4626 - acc: 0.0984 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4626 - acc: 0.0984 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0988 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0972 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0982 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0988 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0982 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0997 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1000 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0994 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0984 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0986 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0986 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0997 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0987 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0990 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0983 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.1011 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0992 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0972 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0983 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0974 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0972 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4626 - acc: 0.0971 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0968 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0970 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4626 - acc: 0.0989 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0990 - val_loss: 2.4627 - val_acc: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0993 - val_loss: 2.4626 - val_acc: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4626 - acc: 0.0983 - val_loss: 2.4625 - val_acc: 0.1000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 15.1730 - acc: 0.2200 - val_loss: 13.9918 - val_acc: 0.3119
# Epoch 2/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.0898 - acc: 0.3094 - val_loss: 12.1484 - val_acc: 0.3539
# Epoch 3/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 11.4054 - acc: 0.3412 - val_loss: 10.6147 - val_acc: 0.3747
# Epoch 4/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 9.9906 - acc: 0.3541 - val_loss: 9.3104 - val_acc: 0.3813
# Epoch 5/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 8.7820 - acc: 0.3704 - val_loss: 8.2040 - val_acc: 0.3889
# Epoch 6/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 7.7566 - acc: 0.3788 - val_loss: 7.2547 - val_acc: 0.4016
# Epoch 7/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 6.8798 - acc: 0.3884 - val_loss: 6.4489 - val_acc: 0.4098
# Epoch 8/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 6.1344 - acc: 0.3948 - val_loss: 5.7645 - val_acc: 0.4121
# Epoch 9/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 5.4965 - acc: 0.3997 - val_loss: 5.1744 - val_acc: 0.4202
# Epoch 10/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.9532 - acc: 0.4036 - val_loss: 4.6753 - val_acc: 0.4200
# Epoch 11/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.4886 - acc: 0.4091 - val_loss: 4.2472 - val_acc: 0.4279
# Epoch 12/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.0913 - acc: 0.4149 - val_loss: 3.8819 - val_acc: 0.4332
# Epoch 13/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.7501 - acc: 0.4180 - val_loss: 3.5676 - val_acc: 0.4375
# Epoch 14/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.4601 - acc: 0.4238 - val_loss: 3.3013 - val_acc: 0.4388
# Epoch 15/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.2099 - acc: 0.4262 - val_loss: 3.0832 - val_acc: 0.4372
# Epoch 16/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.9936 - acc: 0.4304 - val_loss: 2.8705 - val_acc: 0.4450
# Epoch 17/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.8133 - acc: 0.4318 - val_loss: 2.7044 - val_acc: 0.4525
# Epoch 18/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.6523 - acc: 0.4371 - val_loss: 2.5580 - val_acc: 0.4514
# Epoch 19/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.5181 - acc: 0.4409 - val_loss: 2.4395 - val_acc: 0.4524
# Epoch 20/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4035 - acc: 0.4427 - val_loss: 2.3344 - val_acc: 0.4558
# Epoch 21/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.3048 - acc: 0.4439 - val_loss: 2.2424 - val_acc: 0.4575
# Epoch 22/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.2203 - acc: 0.4482 - val_loss: 2.1696 - val_acc: 0.4582
# Epoch 23/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.1462 - acc: 0.4517 - val_loss: 2.1002 - val_acc: 0.4575
# Epoch 24/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.0843 - acc: 0.4520 - val_loss: 2.0407 - val_acc: 0.4651
# Epoch 25/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.0298 - acc: 0.4557 - val_loss: 1.9883 - val_acc: 0.4685
# Epoch 26/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.9820 - acc: 0.4567 - val_loss: 1.9517 - val_acc: 0.4640
# Epoch 27/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9419 - acc: 0.4596 - val_loss: 1.9111 - val_acc: 0.4675
# Epoch 28/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9054 - acc: 0.4607 - val_loss: 1.8920 - val_acc: 0.4659
# Epoch 29/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.8769 - acc: 0.4604 - val_loss: 1.8659 - val_acc: 0.4641
# Epoch 30/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8498 - acc: 0.4643 - val_loss: 1.8312 - val_acc: 0.4722
# Epoch 31/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.8279 - acc: 0.4670 - val_loss: 1.8051 - val_acc: 0.4728
# Epoch 32/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8053 - acc: 0.4672 - val_loss: 1.7953 - val_acc: 0.4705
# Epoch 33/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7913 - acc: 0.4697 - val_loss: 1.8100 - val_acc: 0.4649
# Epoch 34/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7717 - acc: 0.4723 - val_loss: 1.7560 - val_acc: 0.4785
# Epoch 35/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7587 - acc: 0.4735 - val_loss: 1.7628 - val_acc: 0.4687
# Epoch 36/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7472 - acc: 0.4740 - val_loss: 1.7437 - val_acc: 0.4793
# Epoch 37/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.7367 - acc: 0.4775 - val_loss: 1.7308 - val_acc: 0.4793
# Epoch 38/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7260 - acc: 0.4799 - val_loss: 1.7334 - val_acc: 0.4736
# Epoch 39/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7195 - acc: 0.4796 - val_loss: 1.7152 - val_acc: 0.4777
# Epoch 40/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7091 - acc: 0.4797 - val_loss: 1.7012 - val_acc: 0.4924
# Epoch 41/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7065 - acc: 0.4815 - val_loss: 1.7158 - val_acc: 0.4746
# Epoch 42/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6972 - acc: 0.4835 - val_loss: 1.6890 - val_acc: 0.4872
# Epoch 43/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6909 - acc: 0.4843 - val_loss: 1.6980 - val_acc: 0.4839
# Epoch 44/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6883 - acc: 0.4832 - val_loss: 1.6801 - val_acc: 0.4939
# Epoch 45/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6819 - acc: 0.4874 - val_loss: 1.6864 - val_acc: 0.4913
# Epoch 46/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6780 - acc: 0.4884 - val_loss: 1.6875 - val_acc: 0.4851
# Epoch 47/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6739 - acc: 0.4882 - val_loss: 1.6701 - val_acc: 0.4968
# Epoch 48/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.6698 - acc: 0.4893 - val_loss: 1.6872 - val_acc: 0.4887
# Epoch 49/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6693 - acc: 0.4903 - val_loss: 1.6661 - val_acc: 0.4975
# Epoch 50/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.6630 - acc: 0.4928 - val_loss: 1.6796 - val_acc: 0.4902
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 15.2125 - acc: 0.1928 - val_loss: 14.0415 - val_acc: 0.2940
# Epoch 2/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.1571 - acc: 0.2743 - val_loss: 12.2000 - val_acc: 0.3301
# Epoch 3/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 11.4688 - acc: 0.3101 - val_loss: 10.6563 - val_acc: 0.3532
# Epoch 4/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 10.0460 - acc: 0.3276 - val_loss: 9.3446 - val_acc: 0.3668
# Epoch 5/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 8.8343 - acc: 0.3445 - val_loss: 8.2345 - val_acc: 0.3741
# Epoch 6/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 7.8015 - acc: 0.3546 - val_loss: 7.2786 - val_acc: 0.3870
# Epoch 7/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 6.9219 - acc: 0.3629 - val_loss: 6.4696 - val_acc: 0.3921
# Epoch 8/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 6.1722 - acc: 0.3729 - val_loss: 5.7778 - val_acc: 0.3986
# Epoch 9/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 5.5335 - acc: 0.3784 - val_loss: 5.1894 - val_acc: 0.4085
# Epoch 10/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.9870 - acc: 0.3858 - val_loss: 4.6878 - val_acc: 0.4137
# Epoch 11/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.5231 - acc: 0.3886 - val_loss: 4.2599 - val_acc: 0.4172
# Epoch 12/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 4.1220 - acc: 0.3931 - val_loss: 3.8929 - val_acc: 0.4193
# Epoch 13/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.7794 - acc: 0.4002 - val_loss: 3.5743 - val_acc: 0.4269
# Epoch 14/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.4853 - acc: 0.4056 - val_loss: 3.3149 - val_acc: 0.4246
# Epoch 15/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.2386 - acc: 0.4062 - val_loss: 3.0785 - val_acc: 0.4324
# Epoch 16/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.0247 - acc: 0.4127 - val_loss: 2.8831 - val_acc: 0.4365
# Epoch 17/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.8417 - acc: 0.4164 - val_loss: 2.7119 - val_acc: 0.4391
# Epoch 18/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.6820 - acc: 0.4203 - val_loss: 2.5705 - val_acc: 0.4405
# Epoch 19/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.5491 - acc: 0.4217 - val_loss: 2.4458 - val_acc: 0.4465
# Epoch 20/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.4326 - acc: 0.4233 - val_loss: 2.3439 - val_acc: 0.4463
# Epoch 21/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.3346 - acc: 0.4280 - val_loss: 2.2478 - val_acc: 0.4539
# Epoch 22/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.2478 - acc: 0.4309 - val_loss: 2.1736 - val_acc: 0.4528
# Epoch 23/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.1764 - acc: 0.4310 - val_loss: 2.1084 - val_acc: 0.4521
# Epoch 24/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.1129 - acc: 0.4341 - val_loss: 2.0474 - val_acc: 0.4539
# Epoch 25/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.0597 - acc: 0.4353 - val_loss: 1.9959 - val_acc: 0.4609
# Epoch 26/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.0125 - acc: 0.4392 - val_loss: 1.9568 - val_acc: 0.4550
# Epoch 27/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.9713 - acc: 0.4409 - val_loss: 1.9159 - val_acc: 0.4637
# Epoch 28/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9378 - acc: 0.4445 - val_loss: 1.8888 - val_acc: 0.4601
# Epoch 29/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.9097 - acc: 0.4442 - val_loss: 1.8653 - val_acc: 0.4588
# Epoch 30/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8793 - acc: 0.4485 - val_loss: 1.8368 - val_acc: 0.4665
# Epoch 31/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8588 - acc: 0.4489 - val_loss: 1.8133 - val_acc: 0.4654
# Epoch 32/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.8379 - acc: 0.4503 - val_loss: 1.8104 - val_acc: 0.4590
# Epoch 33/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8216 - acc: 0.4503 - val_loss: 1.7824 - val_acc: 0.4699
# Epoch 34/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.8051 - acc: 0.4519 - val_loss: 1.7704 - val_acc: 0.4681
# Epoch 35/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7929 - acc: 0.4574 - val_loss: 1.7504 - val_acc: 0.4739
# Epoch 36/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7795 - acc: 0.4581 - val_loss: 1.7607 - val_acc: 0.4723
# Epoch 37/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7703 - acc: 0.4572 - val_loss: 1.7399 - val_acc: 0.4750
# Epoch 38/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7602 - acc: 0.4596 - val_loss: 1.7447 - val_acc: 0.4658
# Epoch 39/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7527 - acc: 0.4594 - val_loss: 1.7328 - val_acc: 0.4749
# Epoch 40/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7443 - acc: 0.4621 - val_loss: 1.7230 - val_acc: 0.4764
# Epoch 41/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7413 - acc: 0.4647 - val_loss: 1.7195 - val_acc: 0.4749
# Epoch 42/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7346 - acc: 0.4621 - val_loss: 1.7096 - val_acc: 0.4756
# Epoch 43/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7289 - acc: 0.4679 - val_loss: 1.7006 - val_acc: 0.4854
# Epoch 44/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7214 - acc: 0.4688 - val_loss: 1.6986 - val_acc: 0.4794
# Epoch 45/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7179 - acc: 0.4692 - val_loss: 1.7008 - val_acc: 0.4840
# Epoch 46/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.7152 - acc: 0.4661 - val_loss: 1.6963 - val_acc: 0.4789
# Epoch 47/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7086 - acc: 0.4713 - val_loss: 1.6911 - val_acc: 0.4767
# Epoch 48/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7064 - acc: 0.4717 - val_loss: 1.6872 - val_acc: 0.4797
# Epoch 49/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7023 - acc: 0.4713 - val_loss: 1.6908 - val_acc: 0.4808
# Epoch 50/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7019 - acc: 0.4727 - val_loss: 1.6888 - val_acc: 0.4791
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 15.2704 - acc: 0.1529 - val_loss: 14.1367 - val_acc: 0.2711
# Epoch 2/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.2415 - acc: 0.2184 - val_loss: 12.2662 - val_acc: 0.3029
# Epoch 3/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 11.5473 - acc: 0.2494 - val_loss: 10.7179 - val_acc: 0.3256
# Epoch 4/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 10.1162 - acc: 0.2764 - val_loss: 9.3969 - val_acc: 0.3382
# Epoch 5/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 8.9048 - acc: 0.2880 - val_loss: 8.2790 - val_acc: 0.3458
# Epoch 6/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 7.8714 - acc: 0.3065 - val_loss: 7.3334 - val_acc: 0.3508
# Epoch 7/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 6.9942 - acc: 0.3148 - val_loss: 6.5213 - val_acc: 0.3630
# Epoch 8/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 6.2426 - acc: 0.3254 - val_loss: 5.8265 - val_acc: 0.3720
# Epoch 9/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 5.6019 - acc: 0.3339 - val_loss: 5.2333 - val_acc: 0.3788
# Epoch 10/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 5.0540 - acc: 0.3422 - val_loss: 4.7280 - val_acc: 0.3862
# Epoch 11/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.5859 - acc: 0.3494 - val_loss: 4.2985 - val_acc: 0.3831
# Epoch 12/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.1880 - acc: 0.3521 - val_loss: 3.9264 - val_acc: 0.3933
# Epoch 13/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.8471 - acc: 0.3546 - val_loss: 3.6189 - val_acc: 0.3933
# Epoch 14/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.5541 - acc: 0.3610 - val_loss: 3.3539 - val_acc: 0.3933
# Epoch 15/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.3105 - acc: 0.3625 - val_loss: 3.1196 - val_acc: 0.4016
# Epoch 16/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.0953 - acc: 0.3651 - val_loss: 2.9247 - val_acc: 0.4023
# Epoch 17/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.9119 - acc: 0.3703 - val_loss: 2.7588 - val_acc: 0.4089
# Epoch 18/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.7540 - acc: 0.3745 - val_loss: 2.6095 - val_acc: 0.4086
# Epoch 19/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.6198 - acc: 0.3742 - val_loss: 2.4883 - val_acc: 0.4160
# Epoch 20/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.5072 - acc: 0.3761 - val_loss: 2.3802 - val_acc: 0.4154
# Epoch 21/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4078 - acc: 0.3796 - val_loss: 2.2906 - val_acc: 0.4169
# Epoch 22/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.3239 - acc: 0.3814 - val_loss: 2.2166 - val_acc: 0.4235
# Epoch 23/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.2512 - acc: 0.3864 - val_loss: 2.1564 - val_acc: 0.4146
# Epoch 24/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.1904 - acc: 0.3880 - val_loss: 2.0895 - val_acc: 0.4274
# Epoch 25/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.1354 - acc: 0.3892 - val_loss: 2.0381 - val_acc: 0.4303
# Epoch 26/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.0903 - acc: 0.3920 - val_loss: 1.9968 - val_acc: 0.4260
# Epoch 27/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.0496 - acc: 0.3930 - val_loss: 1.9605 - val_acc: 0.4276
# Epoch 28/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.0126 - acc: 0.3991 - val_loss: 1.9265 - val_acc: 0.4328
# Epoch 29/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9857 - acc: 0.3972 - val_loss: 1.8998 - val_acc: 0.4339
# Epoch 30/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.9591 - acc: 0.4004 - val_loss: 1.8779 - val_acc: 0.4358
# Epoch 31/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9382 - acc: 0.4022 - val_loss: 1.8620 - val_acc: 0.4361
# Epoch 32/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.9194 - acc: 0.4037 - val_loss: 1.8390 - val_acc: 0.4402
# Epoch 33/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9017 - acc: 0.4030 - val_loss: 1.8241 - val_acc: 0.4405
# Epoch 34/50
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8865 - acc: 0.4088 - val_loss: 1.8221 - val_acc: 0.4404
# Epoch 35/50
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.8741 - acc: 0.4096 - val_loss: 1.8005 - val_acc: 0.4395
# Epoch 36/50
# ...
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 34us/step - loss: 197.6325 - acc: 0.1841 - val_loss: 35.7077 - val_acc: 0.2326
# Epoch 2/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 15.7896 - acc: 0.1052 - val_loss: 5.1030 - val_acc: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 3.2035 - acc: 0.0993 - val_loss: 2.4707 - val_acc: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4631 - acc: 0.0980 - val_loss: 2.4624 - val_acc: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4625 - acc: 0.0997 - val_loss: 2.4624 - val_acc: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4624 - acc: 0.0999 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4624 - acc: 0.0992 - val_loss: 2.4623 - val_acc: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4623 - acc: 0.0995 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4623 - acc: 0.0995 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4623 - acc: 0.0996 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4622 - acc: 0.0974 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4621 - acc: 0.0983 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4621 - acc: 0.1004 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4621 - acc: 0.0979 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4621 - acc: 0.1012 - val_loss: 2.4620 - val_acc: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4621 - acc: 0.0982 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4620 - acc: 0.1005 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4620 - acc: 0.0987 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4620 - acc: 0.0971 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4620 - acc: 0.0994 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4620 - acc: 0.0980 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.1000 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4619 - acc: 0.1002 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4620 - acc: 0.0990 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0990 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4619 - acc: 0.0995 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.1010 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4619 - acc: 0.0985 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0979 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4618 - acc: 0.0992 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4618 - acc: 0.1013 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4618 - acc: 0.0994 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4618 - acc: 0.0974 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4618 - acc: 0.0980 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4617 - acc: 0.0980 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4617 - acc: 0.0957 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4617 - acc: 0.0995 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4617 - acc: 0.0988 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4616 - acc: 0.0983 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4616 - acc: 0.0984 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4616 - acc: 0.0970 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4616 - acc: 0.0984 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4616 - acc: 0.0985 - val_loss: 2.4614 - val_acc: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4615 - acc: 0.0991 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4615 - acc: 0.0994 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4615 - acc: 0.0975 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4615 - acc: 0.0983 - val_loss: 2.4614 - val_acc: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4614 - acc: 0.1003 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4614 - acc: 0.0976 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4614 - acc: 0.0996 - val_loss: 2.4613 - val_acc: 0.1000
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 35us/step - loss: 197.8597 - acc: 0.1432 - val_loss: 35.7416 - val_acc: 0.1834
# Epoch 2/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 15.8018 - acc: 0.1035 - val_loss: 5.0800 - val_acc: 0.1000
# Epoch 3/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 3.1878 - acc: 0.0976 - val_loss: 2.4694 - val_acc: 0.1000
# Epoch 4/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4629 - acc: 0.1002 - val_loss: 2.4625 - val_acc: 0.1000
# Epoch 5/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4624 - acc: 0.0999 - val_loss: 2.4624 - val_acc: 0.1000
# Epoch 6/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4624 - acc: 0.1006 - val_loss: 2.4623 - val_acc: 0.1000
# Epoch 7/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4624 - acc: 0.0980 - val_loss: 2.4623 - val_acc: 0.1000
# Epoch 8/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4623 - acc: 0.1009 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 9/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4623 - acc: 0.0993 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 10/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4623 - acc: 0.0973 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 11/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4622 - acc: 0.0984 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 12/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4621 - acc: 0.0998 - val_loss: 2.4622 - val_acc: 0.1000
# Epoch 13/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4621 - acc: 0.1012 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 14/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4622 - acc: 0.0974 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 15/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4621 - acc: 0.0988 - val_loss: 2.4620 - val_acc: 0.1000
# Epoch 16/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4620 - acc: 0.0999 - val_loss: 2.4621 - val_acc: 0.1000
# Epoch 17/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4620 - acc: 0.0971 - val_loss: 2.4620 - val_acc: 0.1000
# Epoch 18/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4620 - acc: 0.0981 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 19/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4620 - acc: 0.0974 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 20/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4620 - acc: 0.0982 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 21/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4620 - acc: 0.0982 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 22/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0995 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 23/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0991 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 24/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0997 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 25/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4619 - acc: 0.0994 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 26/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0982 - val_loss: 2.4619 - val_acc: 0.1000
# Epoch 27/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4619 - acc: 0.0982 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 28/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0993 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 29/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4618 - acc: 0.0996 - val_loss: 2.4618 - val_acc: 0.1000
# Epoch 30/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4619 - acc: 0.0986 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 31/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4618 - acc: 0.0977 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 32/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4618 - acc: 0.0964 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 33/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4618 - acc: 0.0982 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 34/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4617 - acc: 0.0973 - val_loss: 2.4617 - val_acc: 0.1000
# Epoch 35/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4617 - acc: 0.0994 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 36/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4617 - acc: 0.0983 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 37/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4617 - acc: 0.0978 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 38/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4616 - acc: 0.0986 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 39/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4616 - acc: 0.0953 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 40/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4616 - acc: 0.0989 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 41/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4616 - acc: 0.1005 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 42/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4615 - acc: 0.0983 - val_loss: 2.4616 - val_acc: 0.1000
# Epoch 43/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4615 - acc: 0.0991 - val_loss: 2.4615 - val_acc: 0.1000
# Epoch 44/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4615 - acc: 0.0971 - val_loss: 2.4614 - val_acc: 0.1000
# Epoch 45/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4615 - acc: 0.1001 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 46/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4615 - acc: 0.0992 - val_loss: 2.4614 - val_acc: 0.1000
# Epoch 47/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4615 - acc: 0.0996 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 48/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4614 - acc: 0.1000 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 49/50
# 50000/50000 [==============================] - 1s 27us/step - loss: 2.4614 - acc: 0.1003 - val_loss: 2.4613 - val_acc: 0.1000
# Epoch 50/50
# 50000/50000 [==============================] - 1s 28us/step - loss: 2.4614 - acc: 0.0971 - val_loss: 2.4613 - val_acc: 0.1000

# %%
"""
Plot results
"""
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = 20

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
